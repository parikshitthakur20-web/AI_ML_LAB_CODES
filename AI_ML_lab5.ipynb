# %%
# Que: Apply Data Normalisation( maximum) techiques - "data type"
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'Type of House': ['Farmhouse', 'Flat', 'Bungalow', 'Hostel', 'PG', 'Flat', 'Bungalow', 'Hostel', 'PG', 'Flat'],
    'Area of House': [100, 62, 110, 37, 25, 12, 5, 25, 12, 21],
    'House Size': ['1BHK', '2BHK', '4BHK', '1BHK', '1BHK', '2BHK', '3BHK', '2BHK', '3BHK', '2BHK'],
    'Cost': [100, 11, 66, 0, 77, 44, 55, 11, 16, 44]
}

df = pd.DataFrame(data)

print("--- Maximum Values in Dataset ---")
print(df.max())

print("\n--- Minimum Values in Dataset ---")
print(df.min())

plt.figure(figsize=(10, 6))
sns.barplot(x="Area of House", y="Cost", hue="Type of House", data=df)

plt.xlabel("Area of house")
plt.ylabel("Cost")
plt.title("House Cost Analysis by Area and Type")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
# Out:
# --- Maximum Values in Dataset ---
# Type of House      PG
# Area of House     110
# House Size       4BHK
# Cost              100
# dtype: object
#
# --- Minimum Values in Dataset ---
# Type of House    Bungalow
# Area of House           5
# House Size           1BHK
# Cost                    0
# dtype: object
